# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7,8,9] # x-axis
y = [9,8,7,6,5,4,3,2,1] # y-axis

# %%
plt.plot(x, y) # matplotlib line plot
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
sns.lineplot(x=x, y=y) # seaborn line plot
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
# pychart
gender = ['Female', 'Male' ]
counts = [80,50]

plt.pie(counts, labels=gender, autopct='%1.3f%%', startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a47d01f380>,
# ...
#  [Text(-1.0285178682643323, -0.39006537229161203, 'Female'),
#   Text(1.028517927162553, 0.3900652169897301, 'Male')],
#  [Text(-0.5610097463259993, -0.21276293034087926, '61.538%'),
#   Text(0.5610097784523016, 0.21276284563076187, '38.462%')])

# %%
sns.countplot(x=counts, hue=gender)
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
plt.hist(y, bins = 5) # matplotlib histogram
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
sns.histplot(y, bins = 5) # seaborn histogram
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
plt.scatter(x, y) # matplotlib scatter plot 
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
sns.scatterplot(x=x, y=y) # seaborn scatter plot
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
plt.bar(x, y,) # matplotlib bar plot
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
sns.barplot(x=x, y=y, color="red") # seaborn bar plot
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
plt.boxplot(y) # matplotlib box plot
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
sns.boxplot(y) # seaborn box plot
plt.xlabel('This is x-axis') # x-axis label
plt.ylabel('This is y-axis') # y-axis label
plt.title('Title of the plot') # title of the plot
# Out:
# Text(0.5, 1.0, 'Title of the plot')

# %%
import plotly.express as px

x = [1, 2, 3, 4, 5, 6, 7, 8, 9]  # x-axis
y = [9, 8, 7, 6, 5, 4, 3, 2, 1]  # y-axis

# Create a DataFrame
import pandas as pd
df = pd.DataFrame({'x': x, 'y': y})

fig = px.line(df, x='x', y='y', title='Title of the plot', labels={'x': 'This is x-axis', 'y': 'This is y-axis'}) # Create a line plot
fig.show() # Show the plot

# %%
import plotly.express as px

# Data for the pie chart
gender = ['Female', 'Male']
counts = [80, 50]

df = pd.DataFrame({'gender': gender, 'counts': counts}) # Create a DataFrame
fig = px.pie(df, names='gender', values='counts', title='Gender Distribution') # Create a pie chart
fig.show() # Show the plot

# %%
import plotly.express as px

# Data for the count plot
df = pd.DataFrame({'gender': gender, 'counts': counts})

fig = px.bar(df, x='counts', color='gender', title='Title of the plot', labels={'counts': 'This is x-axis', 'gender': 'This is y-axis'}) # Create a count plot
fig.show() # Show the plot

# %%
import plotly.express as px

x = [1, 2, 3, 4, 5, 6, 7, 8, 9]  # x-axis
y = [9, 8, 7, 6, 5, 4, 3, 2, 1]  # y-axis

# Data for the histogram
df = pd.DataFrame({'y': y})

fig = px.histogram(df, x='y', nbins=5, title='Title of the plot', labels={'y': 'This is y-axis'}) # Create a histogram
fig.update_layout(xaxis_title='This is x-axis', yaxis_title='This is y-axis') # Update axis labels
fig.show() # Show the plot

# %%
import plotly.express as px

x = [1, 2, 3, 4, 5, 6, 7, 8, 9]  # x-axis
y = [9, 8, 7, 6, 5, 4, 3, 2, 1]  # y-axis

# Data for the scatter plot
df = pd.DataFrame({'x': x, 'y': y})

fig = px.scatter(df, x='x', y='y', title='Title of the plot', labels={'x': 'This is x-axis', 'y': 'This is y-axis'}) # Create a scatter plot
fig.show() # Show the plot

# %%
import plotly.express as px

x = [1, 2, 3, 4, 5, 6, 7, 8, 9]  # x-axis
y = [9, 8, 7, 6, 5, 4, 3, 2, 1]  # y-axis

# Data for the bar graph
df = pd.DataFrame({'x': x, 'y': y})

fig = px.bar(df, x='x', y='y', title='Title of the plot', labels={'x': 'This is x-axis', 'y': 'This is y-axis'}, color_discrete_sequence=['red']) # Create a bar graph
fig.show() # Show the plot

# %%
import plotly.express as px

x = [1, 2, 3, 4, 5, 6, 7, 8, 9]  # x-axis
y = [9, 8, 7, 6, 5, 4, 3, 2, 1]  # y-axis

# Data for the box plot
df = pd.DataFrame({'y': y})

fig = px.box(df, y='y', title='Title of the plot', labels={'y': 'This is y-axis'}) # Create a box plot
fig.update_layout(xaxis_title='This is x-axis', yaxis_title='This is y-axis') # Update axis labels
fig.show() # Show the plot
